# %% [markdown]
# # Data Analysis
# #### The following is the confusion matrix using:
#     - Training set: All hand-drawn training images + ground truths from problem images (0-350)
#     - Test set: Ground truths from problem images (350-706) only
# ##### Class 23 "random alphabets" ground truths were ignored (assume perfect segmentation)

# %%
#Data Initialization
confusion_matrix_index = 3
from data_analysis_data import ground_truth_list_3 as ground_truth_list
from data_analysis_data import prediction_list_3 as prediction_list
#Add base data for confusion matrix
for i in range(64):
    ground_truth_list.append(i)
    prediction_list.append(i)

# %%
dataset_PATH = "C:/Users/JustinSanJuan/Desktop/HKUST/UROP Deep Learning Image-based Structural Analysis/Code/Python/Testing Folder/"

# Compute confusion matrix
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(ground_truth_list,prediction_list)

# Plot non-normalized confusion matrix
from helper_functions import plot_confusion_matrix
from constants import target_names_all
import matplotlib.pyplot as plt
plot_confusion_matrix(cnf_matrix, classes=target_names_all,
                      normalize=False,
                      title='Confusion matrix', 
                      cmap=plt.cm.Blues,PATH=dataset_PATH, name="confusion_matrix_"+str(confusion_matrix_index), verbose = False)
# Out:
# Using TensorFlow backend.
# Figure is saved as: C:/Users/JustinSanJuan/Desktop/HKUST/UROP Deep Learning Image-based Structural Analysis/Code/Python/Testing Folder/confusion_matrix_3.png

# %%
from helper_functions import confusion_matrix_analysis
dataset_PATH = "C:/Users/JustinSanJuan/Desktop/HKUST/UROP Deep Learning Image-based Structural Analysis/Code/Python/Testing Folder/"
name = "confusion_matrix_"+str(confusion_matrix_index)+"_analysis"
min_count = 5
confusion_matrix_analysis(cnf_matrix, dataset_PATH, name, min_count, verbose = False) #Turn verbose on to show data analysis
# Out:
# Data saved as: C:/Users/JustinSanJuan/Desktop/HKUST/UROP Deep Learning Image-based Structural Analysis/Code/Python/Testing Folder/confusion_matrix_3_analysis.txt

# %% [markdown]
# ### Confusion Matrix Results
# #### Results are printed by code.<br>Summary is hand-organized.<br>Error counts less than 5 are ignored.
# ### Total testing data: [3238]<br>Current Accuracy (non-remapped): (89.5%)<br>Current Accuracy (remapped): (89.8%)
#
#
# ### Major issues are:
# #### (4.8%) Similar classes --> "length"<br> (1.9%) Similar classes --> "horizontal beam"<br><br> (1.7%) Roller support up w/ beam --> several classes<br> (1.1%) Measure right --> horizontal beam, UDL
#
# Total: [157] (4.8%)<br>
# [70] measure right --> length<br>
# [53] horizontal beam --> length<br>
# [34] measure left --> length<br>
#
# Total: [62] (1.9%)<br>
# [31] length --> horizontal beam<br>
# [31] measure left --> horizontal beam<br>
#
# ##### Possible Accuracy (non-remapped): (96.2%)<br>Possible Accuracy (remapped): (96.5%)
#
# Total: [56] (1.7%)<br>
# [28] roller support up w/ beam --> pinned support up w/ beam<br>
# [13] roller support up w/ beam --> random alphabet<br>
# [5] roller support up w/ beam --> downwards force<br>
#
# Total: [19] (0.6%)<br>
# [10] measure right --> horizontal beam<br>
# [9] measure right --> uniformly distributed load<br>
#
# ##### Possible Accuracy (non-remapped): (98.5%)<br>Possible Accuracy (remapped): (98.8%)
# ##### The following are uncategorized errors:
#
# Total: [7] (0.2%)<br>
# [7] 0 --> 6<br>
#
# #### The following are negligible due to remapping:
# Total: [10] (0.3%)<br>
# [10] roller support up w/ beam --> roller support up<br>

# %% [markdown]
# ## Action Plan
# ### Problem: (4.8%) Similar classes --> "length"<br> Proposed Solution: More training samples<br><br> Problem: (1.9%) Similar classes --> "horizontal beam"<br> Proposed Solution: More training samples<br><br> Problem: (1.7%) Roller support up w/ beam --> several classes<br>Proposed Solution: More training Samples<br><br> Problem: (1.1%) Measure right --> horizontal beam, UDL <br> Proposed Solution: More training Samples
